# %% [markdown]
# # DAT257x: Reinforcement Learning Explained
#
# ## Lab 5: Temporal Difference Learning
#
# ### Exercise 5.2: SARSA Agent

# %%
import numpy as np
import sys

if "../" not in sys.path:
    sys.path.append("../") 
    
from lib.envs.simple_rooms import SimpleRoomsEnv
from lib.envs.windy_gridworld import WindyGridworldEnv
from lib.envs.cliff_walking import CliffWalkingEnv
from lib.simulation import Experiment
from collections import defaultdict

# %%
class Agent(object):  
        
    def __init__(self, actions):
        self.actions = actions
        self.num_actions = len(actions)

    def act(self, state):
        raise NotImplementedError

# %%
class SarsaAgent(Agent):
    
    def __init__(self, actions, epsilon=0.01, alpha=0.5, gamma=1):
        super(SarsaAgent, self).__init__(actions)
        ## TODO 1
        ## Initialize empty dictionary here
        self.Q = defaultdict(lambda: np.zeros(len(actions)))
        ## In addition, initialize the value of epsilon, alpha and gamma
        self.epsilon = epsilon
        self.alpha = alpha
        self.gamma = gamma

        
    def stateToString(self, state):
        mystring = ""
        if np.isscalar(state):
            mystring = str(state)
        else:
            for digit in state:
                mystring += str(digit)
        return mystring    
    
    def act(self, state):
        stateStr = self.stateToString(state)      
        action = np.random.randint(0, self.num_actions)
        
        ## TODO 2        
        ## Implement epsilon greedy policy here
        choice = None
        if self.epsilon == 0:
            choice = 0
        elif self.epsilon == 1:
            choice = 1
        else:
            choice = np.random.binomial(1, self.epsilon)
            
        if choice == 1:
            return np.random.choice(self.actions)
        else:
            # Try different actions for equiprobable values
            best_actions = np.argwhere(self.Q[stateStr] == np.amax(self.Q[stateStr]))
            action = best_actions[np.random.choice(len(best_actions))]
            return action

    def learn(self, state1, action1, reward, state2, action2):
        state1Str = self.stateToString(state1)
        state2Str = self.stateToString(state2)
        
        ## TODO 3
        ## Implement the sarsa update here
        td_target = reward + self.gamma * self.Q[state2Str][action2]
        td_delta = td_target - self.Q[state1Str][action1]
        self.Q[state1Str][action1] += self.alpha * td_delta
        #print("Qvalues = ",self.Q[state1Str]," reward = ",reward," Action = ",action1)
        
        #self.Q[state1Str][action1] += self.alpha * (reward + self.gamma * self.Q[state2Str][action2]-self.Q[state1Str][action1]) 
        
        """
        SARSA Update
        Q(s,a) <- Q(s,a) + alpha * (reward + gamma * Q(s',a') - Q(s,a))
        or
        Q(s,a) <- Q(s,a) + alpha * (td_target - Q(s,a))
        or
        Q(s,a) <- Q(s,a) + alpha * td_delta
        """

# %%
interactive = True
# %matplotlib nbagg
env = SimpleRoomsEnv()
agent = SarsaAgent(range(env.action_space.n))
experiment = Experiment(env, agent)
experiment.run_sarsa(10, interactive)
# Out:
# <img src="data:image/png;base64,..." width="720">
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  1
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  1
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.   0.   0.   0.5]  reward =  1  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.    0.    0.    0.25]  reward =  0  Action =  [3]
# Qvalues =  [ 0.    0.    0.    0.75]  reward =  1  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  3
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.     0.125  0.     0.   ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.   0.   0.   0.5]  reward =  0  Action =  [3]
# Qvalues =  [ 0.     0.     0.     0.875]  reward =  1  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [0]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.      0.      0.      0.0625]  reward =  0  Action =  [3]
# Qvalues =  [ 0.      0.3125  0.      0.    ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.      0.      0.      0.6875]  reward =  0  Action =  [3]
# Qvalues =  [ 0.      0.      0.      0.9375]  reward =  1  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [1]
# Qvalues =  [ 0.       0.03125  0.       0.     ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.      0.      0.      0.1875]  reward =  0  Action =  [3]
# Qvalues =  [ 0.   0.5  0.   0. ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.      0.      0.      0.8125]  reward =  0  Action =  [3]
# Qvalues =  [ 0.       0.       0.       0.96875]  reward =  1  Action =  [3]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.  0.  0.  0.]  reward =  0  Action =  [2]
# Qvalues =  [ 0.        0.015625  0.        0.      ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.        0.109375  0.        0.      ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.       0.       0.       0.34375]  reward =  0  Action =  [3]
# Qvalues =  [ 0.       0.65625  0.       0.     ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.        0.        0.        0.890625]  reward =  0  Action =  [3]
# Qvalues =  [ 0.         0.         0.         0.9921875]  reward =  1  Action =  [3]
# Qvalues =  [ 0.      0.0625  0.      0.    ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.         0.2265625  0.         0.       ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.   0.   0.   0.5]  reward =  0  Action =  [3]
# Qvalues =  [ 0.         0.7734375  0.         0.       ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.          0.          0.          0.94140625]  reward =  0  Action =  [3]
# Qvalues =  [ 0.          0.          0.          1.02734375]  reward =  1  Action =  [3]
# Qvalues =  [ 0.          0.14453125  0.          0.        ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.          0.36328125  0.          0.        ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.          0.          0.          0.63671875]  reward =  0  Action =  [3]
# Qvalues =  [ 0.          0.85742188  0.          0.        ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.        0.        0.        0.984375]  reward =  0  Action =  [3]
# Qvalues =  [ 0.         0.         0.         1.0859375]  reward =  1  Action =  [3]
# Qvalues =  [ 0.          0.25390625  0.          0.        ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.   0.5  0.   0. ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.          0.          0.          0.74707031]  reward =  0  Action =  [3]
# Qvalues =  [ 0.          0.92089844  0.          0.        ]  reward =  0  Action =  [1]
# Qvalues =  [ 0.          0.          0.          1.03515625]  reward =  0  Action =  [3]
# Qvalues =  [ 0.          0.          0.          1.16992188]  reward =  1  Action =  [3]

# %%
interactive = False
# %matplotlib inline
env = SimpleRoomsEnv()
agent = SarsaAgent(range(env.action_space.n))
experiment = Experiment(env, agent)
experiment.run_sarsa(50, interactive)

# %%
interactive = True
# %matplotlib nbagg
env = CliffWalkingEnv()
agent = SarsaAgent(range(env.action_space.n))
experiment = Experiment(env, agent)
experiment.run_sarsa(10, interactive)
# Out:
# <img src="data:image/png;base64,..." width="720">
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-71-c0415b36eef6> in <module>()
#       4 agent = SarsaAgent(range(env.action_space.n))
#       5 experiment = Experiment(env, agent)
# ----> 6 experiment.run_sarsa(10, interactive)
#
# ~/library/LabFiles/lib/simulation.py in run_sarsa(self, max_number_of_episodes, interactive, display_frequency)
#     232
#     233                 # take action, observe reward and next state
# --> 234                 next_state, reward, done, _ = self.env.step(action)
#     235
#     236                 # choose next action from next state using policy derived from Q
#
# ~/library/LabFiles/lib/envs/cliff_walking.py in step(self, action)
#      63
#      64     def step(self, action):
# ---> 65         reward = self.P[self.s][action][0][2]
#      66         done = self.P[self.s][action][0][3]
#      67         info = {'prob':self.P[self.s][action][0][0]}
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
interactive = False
# %matplotlib inline
env = CliffWalkingEnv()
agent = SarsaAgent(range(env.action_space.n))
experiment = Experiment(env, agent)
experiment.run_sarsa(100, interactive)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-641dfc5bf8e4> in <module>()
#       4 agent = SarsaAgent(range(env.action_space.n))
#       5 experiment = Experiment(env, agent)
# ----> 6 experiment.run_sarsa(100, interactive)
#
# ~/library/LabFiles/lib/simulation.py in run_sarsa(self, max_number_of_episodes, interactive, display_frequency)
#     232
#     233                 # take action, observe reward and next state
# --> 234                 next_state, reward, done, _ = self.env.step(action)
#     235
#     236                 # choose next action from next state using policy derived from Q
#
# ~/library/LabFiles/lib/envs/cliff_walking.py in step(self, action)
#      63
#      64     def step(self, action):
# ---> 65         reward = self.P[self.s][action][0][2]
#      66         done = self.P[self.s][action][0][3]
#      67         info = {'prob':self.P[self.s][action][0][0]}
#
# TypeError: unhashable type: 'numpy.ndarray'

# %%
interactive = False
# %matplotlib inline
env = WindyGridworldEnv()
agent = SarsaAgent(range(env.action_space.n))
experiment = Experiment(env, agent)
experiment.run_sarsa(50, interactive)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-56-9169181e817b> in <module>()
#       4 agent = SarsaAgent(range(env.action_space.n))
#       5 experiment = Experiment(env, agent)
# ----> 6 experiment.run_sarsa(50, interactive)
#
# ~/library/LabFiles/lib/simulation.py in run_sarsa(self, max_number_of_episodes, interactive, display_frequency)
#     232
#     233                 # take action, observe reward and next state
# --> 234                 next_state, reward, done, _ = self.env.step(action)
#     235
#     236                 # choose next action from next state using policy derived from Q
#
# ~/anaconda3_420/lib/python3.5/site-packages/gym/envs/toy_text/discrete.py in step(self, a)
#      52
#      53     def step(self, a):
# ---> 54         transitions = self.P[self.s][a]
#      55         i = categorical_sample([t[0] for t in transitions], self.np_random)
#      56         p, s, r, d= transitions[i]
#
# TypeError: unhashable type: 'numpy.ndarray'
